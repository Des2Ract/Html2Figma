# %%
import os
import sys
import json
import pandas as pd
import math

# Add the parent directory (where utils.py is located) to sys.path to ensure utils module is found
utils_path = os.path.abspath(os.path.join(os.getcwd(), "../../Utils/"))
sys.path.append(utils_path)

# Import utility functions from the utils module
from utils import (
    verb_ratio,
    is_near_gray,
    find_nearest_text_node,
    color_difference,
    collect_text_nodes,
    count_all_descendants,
    count_chars_to_end,
    get_center_of_weight
)

# Global variables for normalization
body_width = None
body_height = None
num_nodes = None
num_chars = None

# %%
def extract_features(node, depth = 0, parent_tag = None, sibling_count = 0,
                    parent_tag_html = None, prev_sibling_tag = None, parent_height = 0,
                    parent_bg_color = None, text_nodes = None):
    """Recursively extract features from a figma node

    Args:
        node : The current node.
        depth : Current depth in the node tree
        parent_tag : figma type of the parent node
        sibling_count : Number of siblings
        parent_tag_html : HTML tag of the parent node
        prev_sibling_tag : HTML tag of the previous sibling
        parent_height : Height of the parent node => (used for normalization)
        parent_bg_color : Background color of the parent => (used for color difference calculation)
        text_nodes : List of text node coordinates => (called at first call only then propagated)

    Returns:
        List of feature vectors

    Steps:
        - Collects text nodes on the first pass only
        - Handles special cases for INPUT tags
        - Extract features
    """
    global body_width
    global body_height
    global num_nodes
    global num_chars

    try:
        # First pass only: Collect text nodes
        if text_nodes is None:
            text_nodes = collect_text_nodes(node)

        features = []

        # Determine tag with special handling for INPUT nodes => (For old dataset checkbox and radio were INPUT)
        tag = node.get("tag", "")
        if tag == "INPUT":
            node_data = node.get("node", {})
            width = node_data.get("width", 0)
            if width < 50:
                node_type = node_data.get("type", "RECTANGLE")
                if node_type == "RECTANGLE":
                    tag = "CHECKBOX"
                elif node_type == "ELLIPSE":
                    tag = "RADIO"
        node["tag"] = tag
        node_data = node.get("node", {})
        node_type = str(node_data.get("type", ""))

        # Extract text-related features
        text = node_data.get("characters", "")
        text_length = len(text)
        word_count = len(text.split()) if text else 0
        contains_number = any(ch.isdigit() for ch in text)
        contains_special_chars = any(not ch.isalnum() and not ch.isspace() for ch in text)

        # Extract structural features
        children = node.get("children", [])
        num_direct_children = len(children)
        is_leaf = 1 if num_direct_children == 0 else 0

        # Initialize child-related features
        child_1_tag, child_2_tag, child_3_tag = None, None, None
        child_1_percent, child_2_percent, child_3_percent = 0.0, 0.0, 0.0

        # Calculate node area and initialize global dimensions
        node_width = node_data.get("width", 0)
        node_height = node_data.get("height", 0)
        if not body_width or body_width == 0:
            body_width = node_width
        if not body_height or body_height == 0:
            body_height = node_height
        node_area = node_width * node_height

        has_placeholder = 0
        is_verb = 0

        # Extract child information if available => (Each child tag and its percentage of the parent area)
        if num_direct_children > 0:
            if len(children) >= 1:
                child_1_tag = children[0].get("tag", "")
                child_1_type = children[0].get("node", {}).get("type", "")
                if child_1_type == "TEXT":
                    if is_verb == 0:
                        is_verb = verb_ratio(children[0].get("node", {}).get("characters", ""))
                    placeholder_fills = children[0].get("node", {}).get("fills", [])
                    placeholder_fills = [fill for fill in placeholder_fills if fill and (color := fill.get("color")) and color.get("a", 1) > 0]
                    for fill in placeholder_fills:
                        if fill.get("type") == "SOLID" and "color" in fill:
                            r, g, b = (
                                int(fill["color"].get("r", 0) * 255),
                                int(fill["color"].get("g", 0) * 255),
                                int(fill["color"].get("b", 0) * 255),
                            )
                            if is_near_gray(r, g, b):
                                has_placeholder = 1
                            break
                if child_1_tag == "INPUT" and children[0].get("node", {}).get("width", 0) < 50:
                    if children[0].get("node", {}).get("type", "RECTANGLE") == "RECTANGLE":
                        child_1_tag = "CHECKBOX"
                    elif children[0].get("node", {}).get("type", "ELLIPSE") == "ELLIPSE":
                        child_1_tag = "RADIO"
                child_1_width = children[0].get("node", {}).get("width", 0)
                child_1_height = children[0].get("node", {}).get("height", 0)
                child_1_area = child_1_width * child_1_height
                child_1_percent = child_1_area / node_area if node_area > 0 else 0.0

            if len(children) >= 2:
                child_2_tag = children[1].get("tag", "")
                child_2_type = children[1].get("node", {}).get("type", "")
                if child_2_type == "TEXT" and is_verb == 0:
                    is_verb = verb_ratio(children[1].get("node", {}).get("characters", ""))
                if child_2_tag == "INPUT" and children[1].get("node", {}).get("width", 0) < 50:
                    if children[1].get("node", {}).get("type", "RECTANGLE") == "RECTANGLE":
                        child_2_tag = "CHECKBOX"
                    elif children[1].get("node", {}).get("type", "ELLIPSE") == "ELLIPSE":
                        child_2_tag = "RADIO"
                child_2_width = children[1].get("node", {}).get("width", 0)
                child_2_height = children[1].get("node", {}).get("height", 0)
                child_2_area = child_2_width * child_2_height
                child_2_percent = child_2_area / node_area if node_area > 0 else 0.0

            if len(children) >= 3:
                child_3_tag = children[2].get("tag", "")
                child_3_type = children[2].get("node", {}).get("type", "")
                if child_3_type == "TEXT" and is_verb == 0:
                    is_verb = verb_ratio(children[2].get("node", {}).get("characters", ""))
                if child_3_tag == "INPUT" and children[2].get("node", {}).get("width", 0) < 50:
                    if children[2].get("node", {}).get("type", "RECTANGLE") == "RECTANGLE":
                        child_3_tag = "CHECKBOX"
                    elif children[2].get("node", {}).get("type", "ELLIPSE") == "ELLIPSE":
                        child_3_tag = "RADIO"
                child_3_width = children[2].get("node", {}).get("width", 0)
                child_3_height = children[2].get("node", {}).get("height", 0)
                child_3_area = child_3_width * child_3_height
                child_3_percent = child_3_area / node_area if node_area > 0 else 0.0

        # Calculate total descendants and characters to the end
        num_children_to_end = count_all_descendants(node)
        if not num_nodes or num_nodes == 0:
            num_nodes = num_children_to_end
        chars_count_to_end = count_chars_to_end(node)
        if not num_chars or num_chars == 0:
            num_chars = chars_count_to_end

        # Initialize feature Vector
        bg_color = None
        feature = {
            "tag": tag,
            "type": node_type,
            "x": node_data.get("x", 0),
            "y": node_data.get("y", 0) / (body_height if body_height else 1),
            "width": node_width / (body_width if body_width else 1),
            "height": node_height / (parent_height if parent_height else node_height if node_height else 1),
            "characters": text,
            "has_text": int(bool(text)),
            "depth": depth,
            "num_direct_children": num_direct_children,
            "num_children_to_end": num_children_to_end / (num_nodes if num_nodes else 1),
            "parent_tag": parent_tag if parent_tag else "",
            "parent_tag_html": parent_tag_html if parent_tag_html else "",
            "sibling_count": sibling_count,
            "prev_sibling_html_tag": prev_sibling_tag if prev_sibling_tag else "",
            "is_leaf": is_leaf,
            "font_size": node_data.get("fontSize", 16),
            "has_font_size": int("fontSize" in node_data),
            "font_name": node_data.get("fontName", {}).get("style", "") if node_data.get("fontName") else "normal",
            "has_text_color": 0, "color_r": 0, "color_g": 0, "color_b": 0,
            "has_background_color": 0, "background_r": 0, "background_g": 0, "background_b": 0,
            "border_radius": 0,
            "border_r": 0, "border_g": 0, "border_b": 0,
            "has_border": 0, "border_opacity": 0,
            "border_weight": node_data.get("strokeWeight", 0),
            "has_shadow": 0, "shadow_r": 0, "shadow_g": 0, "shadow_b": 0,
            "shadow_radius": 0,
            "text_length": text_length,
            "chars_count_to_end": chars_count_to_end / (num_chars if num_chars else 1),
            "word_count": word_count,
            "contains_number": int(contains_number),
            "contains_special_chars": int(contains_special_chars),
            "aspect_ratio": node_width / node_height if node_height > 0 else 0,
            "child_1_html_tag": child_1_tag,
            "child_2_html_tag": child_2_tag,
            "child_3_html_tag": child_3_tag,
            "child_1_percentage_of_parent": child_1_percent,
            "child_2_percentage_of_parent": child_2_percent,
            "child_3_percentage_of_parent": child_3_percent,
            "distinct_background": 0,
            "center_of_weight_diff": get_center_of_weight(node),
            "is_verb": is_verb,
            "has_placeholder": has_placeholder
        }

        # Extract fills (background and text color)
        fills = node_data.get("fills", [])
        fills = [fill for fill in fills if fill and (color := fill.get("color")) and color.get("a", 1) > 0]
        for fill in fills:
            if fill.get("type") == "SOLID" and "color" in fill:
                r, g, b = (
                    int(fill["color"].get("r", 0) * 255),
                    int(fill["color"].get("g", 0) * 255),
                    int(fill["color"].get("b", 0) * 255),
                )
                feature["color_r"], feature["color_g"], feature["color_b"] = r, g, b
                feature["has_text_color"] = 1
                feature["background_r"], feature["background_g"], feature["background_b"] = r, g, b
                feature["has_background_color"] = 1
                a = min(float(fill["color"].get("a", 1)), float(fill.get("opacity", 1)))
                bg_color = (r * a, g * a, b * a)
                if parent_bg_color:
                    feature["distinct_background"] = color_difference(bg_color, parent_bg_color)
                break

        # Extract backgrounds for background color => (special case for Group figma type)
        backgrounds = node_data.get("backgrounds", [])
        for bg in backgrounds:
            if bg.get("type") == "SOLID" and "color" in bg:
                r, g, b = (
                    int(bg["color"].get("r", 0) * 255),
                    int(bg["color"].get("g", 0) * 255),
                    int(bg["color"].get("b", 0) * 255),
                )
                feature["background_r"], feature["background_g"], feature["background_b"] = r, g, b
                feature["has_background_color"] = 1
                break

        # Extract strokes (borders)
        strokes = node_data.get("strokes", [])
        strokes = [stroke for stroke in strokes if stroke and (color := stroke.get("color")) and color.get("a", 1) > 0]
        if strokes:
            stroke = strokes[0]
            feature["has_border"] = 1
            if "color" in stroke:
                feature["border_r"], feature["border_g"], feature["border_b"] = (
                    int(stroke["color"].get("r", 0) * 255),
                    int(stroke["color"].get("g", 0) * 255),
                    int(stroke["color"].get("b", 0) * 255),
                )
            feature["border_opacity"] = stroke.get("opacity", 0)

        # Extract border radius
        br_top_left = node_data.get("topLeftRadius", 0)
        br_top_right = node_data.get("topRightRadius", 0)
        br_bottom_left = node_data.get("bottomLeftRadius", 0)
        br_bottom_right = node_data.get("bottomRightRadius", 0)
        if any([br_top_left, br_top_right, br_bottom_left, br_bottom_right]):
            feature["border_radius"] = (br_top_left + br_top_right + br_bottom_left + br_bottom_right) / 4
            if feature["border_radius"] >= 50:
                feature["border_radius"] = 0

        # Extract shadow effects
        effects = node_data.get("effects", [])
        for effect in effects:
            if effect.get("type") == "DROP_SHADOW":
                feature["has_shadow"] = 1
                if "color" in effect:
                    feature["shadow_r"], feature["shadow_g"], feature["shadow_b"] = (
                        int(effect["color"].get("r", 0) * 255),
                        int(effect["color"].get("g", 0) * 255),
                        int(effect["color"].get("b", 0) * 255),
                    )
                feature["shadow_radius"] = effect.get("radius", 0)
                break

        # Calculate nearest text node distance
        nearest_text_distance = find_nearest_text_node(node, text_nodes)
        area = node_width * node_height if node_width * node_height > 0 else 0
        feature["nearest_text_node_dist"] = (nearest_text_distance+0.01) / (math.sqrt((area+0.001)) if math.sqrt((area+0.001)) else 1)

        features.append(feature)

        # Process children recursively
        prev_sib_tag = None
        for child in children:
            features.extend(extract_features(
                child,
                depth=depth + 1,
                parent_tag=node_type,
                sibling_count=len(children) - 1,
                parent_tag_html=tag,
                prev_sibling_tag=prev_sib_tag,
                parent_height=node_height,
                parent_bg_color=bg_color if feature["has_background_color"] and node_type != "GROUP" else parent_bg_color,
                text_nodes=text_nodes
            ))
            prev_sib_tag = child.get("tag", "")

    except KeyError as e:
        print(f"Error processing node: Missing key {e}. Skipping node.")
        features = []
    except Exception as e:
        print(f"Unexpected error processing node: {e}. Skipping node.")
        features = []

    return features

# %%
# Define input and output paths
DATA_FOLDER = "../../Data/new_json_data9"
OUTPUT_CSV_FILE = "../Output/new_figma_dataset.csv"

# Remove existing output CSV
if os.path.exists(OUTPUT_CSV_FILE):
    os.remove(OUTPUT_CSV_FILE)

# Flag to write header only for the first batch
first_batch = True

# Process each JSON file in the data folder
for filename in os.listdir(DATA_FOLDER):
    if filename.endswith(".json"):
        file_path = os.path.join(DATA_FOLDER, filename)
        print(f"Processing {file_path}...")
        
        try:
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            
            # Extract features starting from the root node
            features_list = extract_features(data, depth=0, parent_tag=None, sibling_count=0,
                                          parent_tag_html=None, parent_height=0, parent_bg_color=None)
            if not features_list:
                print(f"No features extracted from {file_path}. Skipping.")
                continue
            
            # Convert to DataFrame and drop specified columns
            df = pd.DataFrame(features_list)
            # Drop some features => decided by the EDA phase
            columns_to_drop = [
                "x", "y", "characters", "font_size", "font_name", "color_r", "color_g", "color_b",
                "background_r", "background_g", "background_b", "border_r", "border_g", "border_b",
                "border_opacity", "border_weight", "shadow_r", "shadow_g", "shadow_b", "shadow_radius",
                "word_count", "contains_special_chars", "contains_number", "has_shadow", "has_border",
                "has_text_color", "has_text", "depth", "has_font_size", "parent_tag", "is_leaf",
                "child_3_html_tag", "child_3_percentage_of_parent", "num_direct_children", "text_length",
                "chars_count_to_end", "num_children_to_end"
            ]
            df = df.drop(columns=columns_to_drop, errors='ignore')

            # Append to CSV with header for the first batch only
            df.to_csv(OUTPUT_CSV_FILE, mode="a", header=first_batch, index=False)
            first_batch = False
        
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON file {file_path}: {e}. Skipping.")
        except Exception as e:
            print(f"Error processing {file_path}: {e}. Skipping.")

print(f"Extracted features from all JSON files have been saved to {OUTPUT_CSV_FILE}")
# Out:
# Processing ../../Data/new_json_data9\figmaTree_1.json...
# Processing ../../Data/new_json_data9\figmaTree_10.json...
# Processing ../../Data/new_json_data9\figmaTree_100.json...
# Processing ../../Data/new_json_data9\figmaTree_101.json...
# Processing ../../Data/new_json_data9\figmaTree_102.json...
# Processing ../../Data/new_json_data9\figmaTree_103.json...
# Processing ../../Data/new_json_data9\figmaTree_104.json...
# Processing ../../Data/new_json_data9\figmaTree_105.json...
# Processing ../../Data/new_json_data9\figmaTree_107.json...
# Processing ../../Data/new_json_data9\figmaTree_108.json...
# Processing ../../Data/new_json_data9\figmaTree_109.json...
# Processing ../../Data/new_json_data9\figmaTree_11.json...
# Processing ../../Data/new_json_data9\figmaTree_110.json...
# Processing ../../Data/new_json_data9\figmaTree_111.json...
# Processing ../../Data/new_json_data9\figmaTree_112.json...
# Processing ../../Data/new_json_data9\figmaTree_113.json...
# Processing ../../Data/new_json_data9\figmaTree_114.json...
# Processing ../../Data/new_json_data9\figmaTree_115.json...
# Processing ../../Data/new_json_data9\figmaTree_116.json...
# Processing ../../Data/new_json_data9\figmaTree_117.json...
# Processing ../../Data/new_json_data9\figmaTree_118.json...
# Processing ../../Data/new_json_data9\figmaTree_119.json...
# Processing ../../Data/new_json_data9\figmaTree_12.json...
# Processing ../../Data/new_json_data9\figmaTree_120.json...
# Processing ../../Data/new_json_data9\figmaTree_121.json...
# Processing ../../Data/new_json_data9\figmaTree_122.json...
# Processing ../../Data/new_json_data9\figmaTree_123.json...
# Processing ../../Data/new_json_data9\figmaTree_124.json...
# Processing ../../Data/new_json_data9\figmaTree_125.json...
# Processing ../../Data/new_json_data9\figmaTree_126.json...
# Processing ../../Data/new_json_data9\figmaTree_127.json...
# Processing ../../Data/new_json_data9\figmaTree_128.json...
# Processing ../../Data/new_json_data9\figmaTree_129.json...
# Processing ../../Data/new_json_data9\figmaTree_13.json...
# Processing ../../Data/new_json_data9\figmaTree_130.json...
# Processing ../../Data/new_json_data9\figmaTree_131.json...
# Processing ../../Data/new_json_data9\figmaTree_132.json...
# Processing ../../Data/new_json_data9\figmaTree_133.json...
# Processing ../../Data/new_json_data9\figmaTree_134.json...
# Processing ../../Data/new_json_data9\figmaTree_135.json...
# Processing ../../Data/new_json_data9\figmaTree_136.json...
# Processing ../../Data/new_json_data9\figmaTree_137.json...
# Processing ../../Data/new_json_data9\figmaTree_138.json...
# Processing ../../Data/new_json_data9\figmaTree_139.json...
# Processing ../../Data/new_json_data9\figmaTree_14.json...
# Processing ../../Data/new_json_data9\figmaTree_140.json...
# Processing ../../Data/new_json_data9\figmaTree_141.json...
# Processing ../../Data/new_json_data9\figmaTree_142.json...
# Processing ../../Data/new_json_data9\figmaTree_143.json...
# Processing ../../Data/new_json_data9\figmaTree_144.json...
# Processing ../../Data/new_json_data9\figmaTree_145.json...
# Processing ../../Data/new_json_data9\figmaTree_147.json...
# Processing ../../Data/new_json_data9\figmaTree_148.json...
# Processing ../../Data/new_json_data9\figmaTree_149.json...
# Processing ../../Data/new_json_data9\figmaTree_15.json...
# Processing ../../Data/new_json_data9\figmaTree_150.json...
# Processing ../../Data/new_json_data9\figmaTree_151.json...
# Processing ../../Data/new_json_data9\figmaTree_152.json...
# Processing ../../Data/new_json_data9\figmaTree_153.json...
# Processing ../../Data/new_json_data9\figmaTree_154.json...
# Processing ../../Data/new_json_data9\figmaTree_155.json...
# Processing ../../Data/new_json_data9\figmaTree_156.json...
# Processing ../../Data/new_json_data9\figmaTree_157.json...
# Processing ../../Data/new_json_data9\figmaTree_158.json...
# Processing ../../Data/new_json_data9\figmaTree_16.json...
# Processing ../../Data/new_json_data9\figmaTree_160.json...
# Processing ../../Data/new_json_data9\figmaTree_161.json...
# Processing ../../Data/new_json_data9\figmaTree_162.json...
# Processing ../../Data/new_json_data9\figmaTree_163.json...
# Processing ../../Data/new_json_data9\figmaTree_164.json...
# Processing ../../Data/new_json_data9\figmaTree_165.json...
# Processing ../../Data/new_json_data9\figmaTree_166.json...
# Processing ../../Data/new_json_data9\figmaTree_167.json...
# Processing ../../Data/new_json_data9\figmaTree_168.json...
# Processing ../../Data/new_json_data9\figmaTree_169.json...
# Processing ../../Data/new_json_data9\figmaTree_17.json...
# Processing ../../Data/new_json_data9\figmaTree_170.json...
# Processing ../../Data/new_json_data9\figmaTree_171.json...
# Processing ../../Data/new_json_data9\figmaTree_172.json...
# Processing ../../Data/new_json_data9\figmaTree_173.json...
# Processing ../../Data/new_json_data9\figmaTree_174.json...
# Processing ../../Data/new_json_data9\figmaTree_175.json...
# Processing ../../Data/new_json_data9\figmaTree_176.json...
# Processing ../../Data/new_json_data9\figmaTree_177.json...
# Processing ../../Data/new_json_data9\figmaTree_178.json...
# Processing ../../Data/new_json_data9\figmaTree_179.json...
# Processing ../../Data/new_json_data9\figmaTree_18.json...
# Processing ../../Data/new_json_data9\figmaTree_180.json...
# Processing ../../Data/new_json_data9\figmaTree_181.json...
# Processing ../../Data/new_json_data9\figmaTree_182.json...
# Processing ../../Data/new_json_data9\figmaTree_183.json...
# Processing ../../Data/new_json_data9\figmaTree_184.json...
# Processing ../../Data/new_json_data9\figmaTree_185.json...
# Processing ../../Data/new_json_data9\figmaTree_186.json...
# Processing ../../Data/new_json_data9\figmaTree_187.json...
# Processing ../../Data/new_json_data9\figmaTree_188.json...
# Processing ../../Data/new_json_data9\figmaTree_189.json...
# Processing ../../Data/new_json_data9\figmaTree_19.json...
# Processing ../../Data/new_json_data9\figmaTree_190.json...
# Processing ../../Data/new_json_data9\figmaTree_191.json...
# Processing ../../Data/new_json_data9\figmaTree_192.json...
# Processing ../../Data/new_json_data9\figmaTree_193.json...
# Processing ../../Data/new_json_data9\figmaTree_194.json...
# Processing ../../Data/new_json_data9\figmaTree_195.json...
# Processing ../../Data/new_json_data9\figmaTree_196.json...
# Processing ../../Data/new_json_data9\figmaTree_197.json...
# Processing ../../Data/new_json_data9\figmaTree_198.json...
# Processing ../../Data/new_json_data9\figmaTree_199.json...
# Processing ../../Data/new_json_data9\figmaTree_2.json...
# Processing ../../Data/new_json_data9\figmaTree_20.json...
# Processing ../../Data/new_json_data9\figmaTree_200.json...
# Processing ../../Data/new_json_data9\figmaTree_201.json...
# Processing ../../Data/new_json_data9\figmaTree_202.json...
# Processing ../../Data/new_json_data9\figmaTree_203.json...
# Processing ../../Data/new_json_data9\figmaTree_204.json...
# Processing ../../Data/new_json_data9\figmaTree_205.json...
# Processing ../../Data/new_json_data9\figmaTree_206.json...
# Processing ../../Data/new_json_data9\figmaTree_207.json...
# Processing ../../Data/new_json_data9\figmaTree_208.json...
# Processing ../../Data/new_json_data9\figmaTree_209.json...
# Processing ../../Data/new_json_data9\figmaTree_21.json...
# Processing ../../Data/new_json_data9\figmaTree_210.json...
# Processing ../../Data/new_json_data9\figmaTree_211.json...
# Processing ../../Data/new_json_data9\figmaTree_212.json...
# Processing ../../Data/new_json_data9\figmaTree_213.json...
# Processing ../../Data/new_json_data9\figmaTree_214.json...
# Processing ../../Data/new_json_data9\figmaTree_215.json...
# Processing ../../Data/new_json_data9\figmaTree_216.json...
# Processing ../../Data/new_json_data9\figmaTree_217.json...
# Processing ../../Data/new_json_data9\figmaTree_218.json...
# Processing ../../Data/new_json_data9\figmaTree_219.json...
# Processing ../../Data/new_json_data9\figmaTree_22.json...
# Processing ../../Data/new_json_data9\figmaTree_220.json...
# Processing ../../Data/new_json_data9\figmaTree_221.json...
# Processing ../../Data/new_json_data9\figmaTree_223.json...
# Processing ../../Data/new_json_data9\figmaTree_224.json...
# Processing ../../Data/new_json_data9\figmaTree_225.json...
# Processing ../../Data/new_json_data9\figmaTree_226.json...
# Processing ../../Data/new_json_data9\figmaTree_227.json...
# Processing ../../Data/new_json_data9\figmaTree_228.json...
# Processing ../../Data/new_json_data9\figmaTree_229.json...
# Processing ../../Data/new_json_data9\figmaTree_23.json...
# Processing ../../Data/new_json_data9\figmaTree_230.json...
# Processing ../../Data/new_json_data9\figmaTree_231.json...
# Processing ../../Data/new_json_data9\figmaTree_232.json...
# Processing ../../Data/new_json_data9\figmaTree_233.json...
# Processing ../../Data/new_json_data9\figmaTree_234.json...
# Processing ../../Data/new_json_data9\figmaTree_235.json...
# Processing ../../Data/new_json_data9\figmaTree_236.json...
# Processing ../../Data/new_json_data9\figmaTree_237.json...
# Processing ../../Data/new_json_data9\figmaTree_238.json...
# Processing ../../Data/new_json_data9\figmaTree_239.json...
# Processing ../../Data/new_json_data9\figmaTree_24.json...
# Processing ../../Data/new_json_data9\figmaTree_240.json...
# Processing ../../Data/new_json_data9\figmaTree_241.json...
# Processing ../../Data/new_json_data9\figmaTree_242.json...
# Processing ../../Data/new_json_data9\figmaTree_243.json...
# Processing ../../Data/new_json_data9\figmaTree_244.json...
# Processing ../../Data/new_json_data9\figmaTree_245.json...
# Processing ../../Data/new_json_data9\figmaTree_246.json...
# Processing ../../Data/new_json_data9\figmaTree_247.json...
# Processing ../../Data/new_json_data9\figmaTree_248.json...
# Processing ../../Data/new_json_data9\figmaTree_249.json...
# Processing ../../Data/new_json_data9\figmaTree_25.json...
# Processing ../../Data/new_json_data9\figmaTree_250.json...
# Processing ../../Data/new_json_data9\figmaTree_251.json...
# Processing ../../Data/new_json_data9\figmaTree_252.json...
# Processing ../../Data/new_json_data9\figmaTree_253.json...
# Processing ../../Data/new_json_data9\figmaTree_254.json...
# Processing ../../Data/new_json_data9\figmaTree_255.json...
# Processing ../../Data/new_json_data9\figmaTree_256.json...
# Processing ../../Data/new_json_data9\figmaTree_257.json...
# Processing ../../Data/new_json_data9\figmaTree_258.json...
# Processing ../../Data/new_json_data9\figmaTree_259.json...
# Processing ../../Data/new_json_data9\figmaTree_260.json...
# Processing ../../Data/new_json_data9\figmaTree_261.json...
# Processing ../../Data/new_json_data9\figmaTree_262.json...
# Processing ../../Data/new_json_data9\figmaTree_263.json...
# Processing ../../Data/new_json_data9\figmaTree_264.json...
# Processing ../../Data/new_json_data9\figmaTree_265.json...
# Processing ../../Data/new_json_data9\figmaTree_266.json...
# Processing ../../Data/new_json_data9\figmaTree_267.json...
# Processing ../../Data/new_json_data9\figmaTree_268.json...
# Processing ../../Data/new_json_data9\figmaTree_269.json...
# Processing ../../Data/new_json_data9\figmaTree_27.json...
# Processing ../../Data/new_json_data9\figmaTree_270.json...
# Processing ../../Data/new_json_data9\figmaTree_271.json...
# Processing ../../Data/new_json_data9\figmaTree_272.json...
# Processing ../../Data/new_json_data9\figmaTree_273.json...
# Processing ../../Data/new_json_data9\figmaTree_274.json...
# Processing ../../Data/new_json_data9\figmaTree_275.json...
# Processing ../../Data/new_json_data9\figmaTree_276.json...
# Processing ../../Data/new_json_data9\figmaTree_277.json...
# Processing ../../Data/new_json_data9\figmaTree_278.json...
# Processing ../../Data/new_json_data9\figmaTree_279.json...
# Processing ../../Data/new_json_data9\figmaTree_28.json...
# Processing ../../Data/new_json_data9\figmaTree_280.json...
# Processing ../../Data/new_json_data9\figmaTree_281.json...
# Processing ../../Data/new_json_data9\figmaTree_282.json...
# Processing ../../Data/new_json_data9\figmaTree_283.json...
# Processing ../../Data/new_json_data9\figmaTree_284.json...
# Processing ../../Data/new_json_data9\figmaTree_285.json...
# Processing ../../Data/new_json_data9\figmaTree_286.json...
# Processing ../../Data/new_json_data9\figmaTree_287.json...
# Processing ../../Data/new_json_data9\figmaTree_288.json...
# Processing ../../Data/new_json_data9\figmaTree_29.json...
# Processing ../../Data/new_json_data9\figmaTree_290.json...
# Processing ../../Data/new_json_data9\figmaTree_291.json...
# Processing ../../Data/new_json_data9\figmaTree_292.json...
# Processing ../../Data/new_json_data9\figmaTree_293.json...
# Processing ../../Data/new_json_data9\figmaTree_294.json...
# Processing ../../Data/new_json_data9\figmaTree_295.json...
# Processing ../../Data/new_json_data9\figmaTree_296.json...
# Processing ../../Data/new_json_data9\figmaTree_297.json...
# Processing ../../Data/new_json_data9\figmaTree_298.json...
# Processing ../../Data/new_json_data9\figmaTree_299.json...
# Processing ../../Data/new_json_data9\figmaTree_3.json...
# Processing ../../Data/new_json_data9\figmaTree_30.json...
# Processing ../../Data/new_json_data9\figmaTree_300.json...
# Processing ../../Data/new_json_data9\figmaTree_31.json...
# Processing ../../Data/new_json_data9\figmaTree_32.json...
# Processing ../../Data/new_json_data9\figmaTree_33.json...
# Processing ../../Data/new_json_data9\figmaTree_34.json...
# Processing ../../Data/new_json_data9\figmaTree_35.json...
# Processing ../../Data/new_json_data9\figmaTree_36.json...
# Processing ../../Data/new_json_data9\figmaTree_37.json...
# Processing ../../Data/new_json_data9\figmaTree_38.json...
# Processing ../../Data/new_json_data9\figmaTree_39.json...
# Processing ../../Data/new_json_data9\figmaTree_4.json...
# Processing ../../Data/new_json_data9\figmaTree_40.json...
# Processing ../../Data/new_json_data9\figmaTree_41.json...
# Processing ../../Data/new_json_data9\figmaTree_42.json...
# Processing ../../Data/new_json_data9\figmaTree_43.json...
# Processing ../../Data/new_json_data9\figmaTree_45.json...
# Processing ../../Data/new_json_data9\figmaTree_47.json...
# Processing ../../Data/new_json_data9\figmaTree_49.json...
# Processing ../../Data/new_json_data9\figmaTree_5.json...
# Processing ../../Data/new_json_data9\figmaTree_50.json...
# Processing ../../Data/new_json_data9\figmaTree_51.json...
# Processing ../../Data/new_json_data9\figmaTree_54.json...
# Processing ../../Data/new_json_data9\figmaTree_55.json...
# Processing ../../Data/new_json_data9\figmaTree_57.json...
# Processing ../../Data/new_json_data9\figmaTree_58.json...
# Processing ../../Data/new_json_data9\figmaTree_59.json...
# Processing ../../Data/new_json_data9\figmaTree_6.json...
# Processing ../../Data/new_json_data9\figmaTree_60.json...
# Processing ../../Data/new_json_data9\figmaTree_61.json...
# Processing ../../Data/new_json_data9\figmaTree_62.json...
# Processing ../../Data/new_json_data9\figmaTree_63.json...
# Processing ../../Data/new_json_data9\figmaTree_65.json...
# Processing ../../Data/new_json_data9\figmaTree_66.json...
# Processing ../../Data/new_json_data9\figmaTree_67.json...
# Processing ../../Data/new_json_data9\figmaTree_68.json...
# Processing ../../Data/new_json_data9\figmaTree_69.json...
# Processing ../../Data/new_json_data9\figmaTree_70.json...
# Processing ../../Data/new_json_data9\figmaTree_71.json...
# Processing ../../Data/new_json_data9\figmaTree_72.json...
# Processing ../../Data/new_json_data9\figmaTree_73.json...
# Processing ../../Data/new_json_data9\figmaTree_74.json...
# Processing ../../Data/new_json_data9\figmaTree_75.json...
# Processing ../../Data/new_json_data9\figmaTree_76.json...
# Processing ../../Data/new_json_data9\figmaTree_77.json...
# Processing ../../Data/new_json_data9\figmaTree_78.json...
# Processing ../../Data/new_json_data9\figmaTree_79.json...
# Processing ../../Data/new_json_data9\figmaTree_8.json...
# Processing ../../Data/new_json_data9\figmaTree_81.json...
# Processing ../../Data/new_json_data9\figmaTree_82.json...
# Processing ../../Data/new_json_data9\figmaTree_83.json...
# Processing ../../Data/new_json_data9\figmaTree_84.json...
# Processing ../../Data/new_json_data9\figmaTree_86.json...
# Processing ../../Data/new_json_data9\figmaTree_88.json...
# Processing ../../Data/new_json_data9\figmaTree_89.json...
# Processing ../../Data/new_json_data9\figmaTree_9.json...
# Processing ../../Data/new_json_data9\figmaTree_90.json...
# Processing ../../Data/new_json_data9\figmaTree_91.json...
# Processing ../../Data/new_json_data9\figmaTree_92.json...
# Processing ../../Data/new_json_data9\figmaTree_94.json...
# Processing ../../Data/new_json_data9\figmaTree_95.json...
# Processing ../../Data/new_json_data9\figmaTree_96.json...
# Processing ../../Data/new_json_data9\figmaTree_97.json...
# Processing ../../Data/new_json_data9\figmaTree_99.json...
# Processing ../../Data/new_json_data9\PAGE_1.json...
# Processing ../../Data/new_json_data9\PAGE_10.json...
# Processing ../../Data/new_json_data9\PAGE_101.json...
# Processing ../../Data/new_json_data9\PAGE_102.json...
# Processing ../../Data/new_json_data9\PAGE_103.json...
# Processing ../../Data/new_json_data9\PAGE_104.json...
# Processing ../../Data/new_json_data9\PAGE_105.json...
# Processing ../../Data/new_json_data9\PAGE_106.json...
# Processing ../../Data/new_json_data9\PAGE_107.json...
# Processing ../../Data/new_json_data9\PAGE_108.json...
# Processing ../../Data/new_json_data9\PAGE_109.json...
# Processing ../../Data/new_json_data9\PAGE_11.json...
# Processing ../../Data/new_json_data9\PAGE_110.json...
# Processing ../../Data/new_json_data9\PAGE_111.json...
# Processing ../../Data/new_json_data9\PAGE_112.json...
# Processing ../../Data/new_json_data9\PAGE_113.json...
# Processing ../../Data/new_json_data9\PAGE_114.json...
# Processing ../../Data/new_json_data9\PAGE_115.json...
# Processing ../../Data/new_json_data9\PAGE_116.json...
# Processing ../../Data/new_json_data9\PAGE_117.json...
# Processing ../../Data/new_json_data9\PAGE_118.json...
# Processing ../../Data/new_json_data9\PAGE_119.json...
# Processing ../../Data/new_json_data9\PAGE_12.json...
# Processing ../../Data/new_json_data9\PAGE_120.json...
# Processing ../../Data/new_json_data9\PAGE_121.json...
# Processing ../../Data/new_json_data9\PAGE_122.json...
# Processing ../../Data/new_json_data9\PAGE_123.json...
# Processing ../../Data/new_json_data9\PAGE_124.json...
# Processing ../../Data/new_json_data9\PAGE_125.json...
# Processing ../../Data/new_json_data9\PAGE_126.json...
# Processing ../../Data/new_json_data9\PAGE_127.json...
# Processing ../../Data/new_json_data9\PAGE_128.json...
# Processing ../../Data/new_json_data9\PAGE_129.json...
# Processing ../../Data/new_json_data9\PAGE_13.json...
# Processing ../../Data/new_json_data9\PAGE_130.json...
# Processing ../../Data/new_json_data9\PAGE_131.json...
# Processing ../../Data/new_json_data9\PAGE_132.json...
# Processing ../../Data/new_json_data9\PAGE_133.json...
# Processing ../../Data/new_json_data9\PAGE_134.json...
# Processing ../../Data/new_json_data9\PAGE_135.json...
# Processing ../../Data/new_json_data9\PAGE_136.json...
# Processing ../../Data/new_json_data9\PAGE_137.json...
# Processing ../../Data/new_json_data9\PAGE_138.json...
# Processing ../../Data/new_json_data9\PAGE_139.json...
# Processing ../../Data/new_json_data9\PAGE_14.json...
# Processing ../../Data/new_json_data9\PAGE_140.json...
# Processing ../../Data/new_json_data9\PAGE_141.json...
# Processing ../../Data/new_json_data9\PAGE_142.json...
# Processing ../../Data/new_json_data9\PAGE_143.json...
# Processing ../../Data/new_json_data9\PAGE_144.json...
# Processing ../../Data/new_json_data9\PAGE_145.json...
# Processing ../../Data/new_json_data9\PAGE_146.json...
# Processing ../../Data/new_json_data9\PAGE_147.json...
# Processing ../../Data/new_json_data9\PAGE_148.json...
# Processing ../../Data/new_json_data9\PAGE_149.json...
# Processing ../../Data/new_json_data9\PAGE_15.json...
# Processing ../../Data/new_json_data9\PAGE_150.json...
# Processing ../../Data/new_json_data9\PAGE_151.json...
# Processing ../../Data/new_json_data9\PAGE_152.json...
# Processing ../../Data/new_json_data9\PAGE_153.json...
# Processing ../../Data/new_json_data9\PAGE_154.json...
# Processing ../../Data/new_json_data9\PAGE_155.json...
# Processing ../../Data/new_json_data9\PAGE_156.json...
# Processing ../../Data/new_json_data9\PAGE_157.json...
# Processing ../../Data/new_json_data9\PAGE_158.json...
# Processing ../../Data/new_json_data9\PAGE_159.json...
# Processing ../../Data/new_json_data9\PAGE_16.json...
# Processing ../../Data/new_json_data9\PAGE_160.json...
# Processing ../../Data/new_json_data9\PAGE_161.json...
# Processing ../../Data/new_json_data9\PAGE_162.json...
# Processing ../../Data/new_json_data9\PAGE_163.json...
# Processing ../../Data/new_json_data9\PAGE_164.json...
# Processing ../../Data/new_json_data9\PAGE_165.json...
# Processing ../../Data/new_json_data9\PAGE_166.json...
# Processing ../../Data/new_json_data9\PAGE_167.json...
# Processing ../../Data/new_json_data9\PAGE_168.json...
# Processing ../../Data/new_json_data9\PAGE_169.json...
# Processing ../../Data/new_json_data9\PAGE_17.json...
# Processing ../../Data/new_json_data9\PAGE_170.json...
# Processing ../../Data/new_json_data9\PAGE_171.json...
# Processing ../../Data/new_json_data9\PAGE_172.json...
# Processing ../../Data/new_json_data9\PAGE_173.json...
# Processing ../../Data/new_json_data9\PAGE_174.json...
# Processing ../../Data/new_json_data9\PAGE_175.json...
# Processing ../../Data/new_json_data9\PAGE_176.json...
# Processing ../../Data/new_json_data9\PAGE_177.json...
# Processing ../../Data/new_json_data9\PAGE_178.json...
# Processing ../../Data/new_json_data9\PAGE_179.json...
# Processing ../../Data/new_json_data9\PAGE_18.json...
# Processing ../../Data/new_json_data9\PAGE_180.json...
# Processing ../../Data/new_json_data9\PAGE_181.json...
# Processing ../../Data/new_json_data9\PAGE_182.json...
# Processing ../../Data/new_json_data9\PAGE_183.json...
# Processing ../../Data/new_json_data9\PAGE_184.json...
# Processing ../../Data/new_json_data9\PAGE_185.json...
# Processing ../../Data/new_json_data9\PAGE_186.json...
# Processing ../../Data/new_json_data9\PAGE_187.json...
# Processing ../../Data/new_json_data9\PAGE_188.json...
# Processing ../../Data/new_json_data9\PAGE_189.json...
# Processing ../../Data/new_json_data9\PAGE_19.json...
# Processing ../../Data/new_json_data9\PAGE_190.json...
# Processing ../../Data/new_json_data9\PAGE_191.json...
# Processing ../../Data/new_json_data9\PAGE_192.json...
# Processing ../../Data/new_json_data9\PAGE_193.json...
# Processing ../../Data/new_json_data9\PAGE_194.json...
# Processing ../../Data/new_json_data9\PAGE_195.json...
# Processing ../../Data/new_json_data9\PAGE_196.json...
# Processing ../../Data/new_json_data9\PAGE_197.json...
# Processing ../../Data/new_json_data9\PAGE_198.json...
# Processing ../../Data/new_json_data9\PAGE_199.json...
# Processing ../../Data/new_json_data9\PAGE_2.json...
# Processing ../../Data/new_json_data9\PAGE_20.json...
# Processing ../../Data/new_json_data9\PAGE_200.json...
# Processing ../../Data/new_json_data9\PAGE_201.json...
# Processing ../../Data/new_json_data9\PAGE_202.json...
# Processing ../../Data/new_json_data9\PAGE_203.json...
# Processing ../../Data/new_json_data9\PAGE_204.json...
# Processing ../../Data/new_json_data9\PAGE_205.json...
# Processing ../../Data/new_json_data9\PAGE_206.json...
# Processing ../../Data/new_json_data9\PAGE_207.json...
# Processing ../../Data/new_json_data9\PAGE_208.json...
# Processing ../../Data/new_json_data9\PAGE_209.json...
# Processing ../../Data/new_json_data9\PAGE_21.json...
# Processing ../../Data/new_json_data9\PAGE_210.json...
# Processing ../../Data/new_json_data9\PAGE_211.json...
# Processing ../../Data/new_json_data9\PAGE_212.json...
# Processing ../../Data/new_json_data9\PAGE_213.json...
# Processing ../../Data/new_json_data9\PAGE_214.json...
# Processing ../../Data/new_json_data9\PAGE_215.json...
# Processing ../../Data/new_json_data9\PAGE_216.json...
# Processing ../../Data/new_json_data9\PAGE_217.json...
# Processing ../../Data/new_json_data9\PAGE_218.json...
# Processing ../../Data/new_json_data9\PAGE_219.json...
# Processing ../../Data/new_json_data9\PAGE_22.json...
# Processing ../../Data/new_json_data9\PAGE_220.json...
# Processing ../../Data/new_json_data9\PAGE_221.json...
# Processing ../../Data/new_json_data9\PAGE_222.json...
# Processing ../../Data/new_json_data9\PAGE_223.json...
# Processing ../../Data/new_json_data9\PAGE_224.json...
# Processing ../../Data/new_json_data9\PAGE_225.json...
# Processing ../../Data/new_json_data9\PAGE_226.json...
# Processing ../../Data/new_json_data9\PAGE_227.json...
# Processing ../../Data/new_json_data9\PAGE_228.json...
# Processing ../../Data/new_json_data9\PAGE_229.json...
# Processing ../../Data/new_json_data9\PAGE_23.json...
# Processing ../../Data/new_json_data9\PAGE_230.json...
# Processing ../../Data/new_json_data9\PAGE_231.json...
# Processing ../../Data/new_json_data9\PAGE_232.json...
# Processing ../../Data/new_json_data9\PAGE_233.json...
# Processing ../../Data/new_json_data9\PAGE_234.json...
# Processing ../../Data/new_json_data9\PAGE_235.json...
# Processing ../../Data/new_json_data9\PAGE_236.json...
# Processing ../../Data/new_json_data9\PAGE_237.json...
# Processing ../../Data/new_json_data9\PAGE_238.json...
# Processing ../../Data/new_json_data9\PAGE_239.json...
# Processing ../../Data/new_json_data9\PAGE_24.json...
# Processing ../../Data/new_json_data9\PAGE_240.json...
# Processing ../../Data/new_json_data9\PAGE_241.json...
# Processing ../../Data/new_json_data9\PAGE_242.json...
# Processing ../../Data/new_json_data9\PAGE_243.json...
# Processing ../../Data/new_json_data9\PAGE_244.json...
# Processing ../../Data/new_json_data9\PAGE_245.json...
# Processing ../../Data/new_json_data9\PAGE_246.json...
# Processing ../../Data/new_json_data9\PAGE_247.json...
# Processing ../../Data/new_json_data9\PAGE_248.json...
# Processing ../../Data/new_json_data9\PAGE_249.json...
# Processing ../../Data/new_json_data9\PAGE_25.json...
# Processing ../../Data/new_json_data9\PAGE_250.json...
# Processing ../../Data/new_json_data9\PAGE_251.json...
# Processing ../../Data/new_json_data9\PAGE_252.json...
# Processing ../../Data/new_json_data9\PAGE_253.json...
# Processing ../../Data/new_json_data9\PAGE_254.json...
# Processing ../../Data/new_json_data9\PAGE_255.json...
# Processing ../../Data/new_json_data9\PAGE_256.json...
# Processing ../../Data/new_json_data9\PAGE_26.json...
# Processing ../../Data/new_json_data9\PAGE_27.json...
# Processing ../../Data/new_json_data9\PAGE_28.json...
# Processing ../../Data/new_json_data9\PAGE_29.json...
# Processing ../../Data/new_json_data9\PAGE_3.json...
# Processing ../../Data/new_json_data9\PAGE_30.json...
# Processing ../../Data/new_json_data9\PAGE_31.json...
# Processing ../../Data/new_json_data9\PAGE_32.json...
# Processing ../../Data/new_json_data9\PAGE_33.json...
# Processing ../../Data/new_json_data9\PAGE_34.json...
# Processing ../../Data/new_json_data9\PAGE_35.json...
# Processing ../../Data/new_json_data9\PAGE_36.json...
# Processing ../../Data/new_json_data9\PAGE_37.json...
# Processing ../../Data/new_json_data9\PAGE_38.json...
# Processing ../../Data/new_json_data9\PAGE_39.json...
# Processing ../../Data/new_json_data9\PAGE_4.json...
# Processing ../../Data/new_json_data9\PAGE_40.json...
# Processing ../../Data/new_json_data9\PAGE_41.json...
# Processing ../../Data/new_json_data9\PAGE_42.json...
# Processing ../../Data/new_json_data9\PAGE_43.json...
# Processing ../../Data/new_json_data9\PAGE_44.json...
# Processing ../../Data/new_json_data9\PAGE_45.json...
# Processing ../../Data/new_json_data9\PAGE_46.json...
# Processing ../../Data/new_json_data9\PAGE_47.json...
# Processing ../../Data/new_json_data9\PAGE_48.json...
# Processing ../../Data/new_json_data9\PAGE_49.json...
# Processing ../../Data/new_json_data9\PAGE_5.json...
# Processing ../../Data/new_json_data9\PAGE_50.json...
# Processing ../../Data/new_json_data9\PAGE_51.json...
# Processing ../../Data/new_json_data9\PAGE_52.json...
# Processing ../../Data/new_json_data9\PAGE_53.json...
# Processing ../../Data/new_json_data9\PAGE_54.json...
# Processing ../../Data/new_json_data9\PAGE_55.json...
# Processing ../../Data/new_json_data9\PAGE_56.json...
# Processing ../../Data/new_json_data9\PAGE_57.json...
# Processing ../../Data/new_json_data9\PAGE_58.json...
# Processing ../../Data/new_json_data9\PAGE_59.json...
# Processing ../../Data/new_json_data9\PAGE_6.json...
# Processing ../../Data/new_json_data9\PAGE_60.json...
# Processing ../../Data/new_json_data9\PAGE_61.json...
# Processing ../../Data/new_json_data9\PAGE_62.json...
# Processing ../../Data/new_json_data9\PAGE_63.json...
# Processing ../../Data/new_json_data9\PAGE_64.json...
# Processing ../../Data/new_json_data9\PAGE_65.json...
# Processing ../../Data/new_json_data9\PAGE_7.json...
# Processing ../../Data/new_json_data9\PAGE_8.json...
# Processing ../../Data/new_json_data9\PAGE_9.json...
# Extracted features from all JSON files have been saved to ../Output/new_figma_dataset.csv
